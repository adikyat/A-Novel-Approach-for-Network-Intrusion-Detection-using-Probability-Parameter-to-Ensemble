# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Comment this if the data visualisations doesn't work on your side
# %matplotlib inline

plt.style.use('bmh')

# %%
df= pd.read_csv('drive/My Drive/BE FINAL/Friday-WorkingHours-Afternoon-DDos.pcap_ISCX.csv', index_col=None)
df.head()
# Out:
#     Destination Port   Flow Duration  ...   Idle Min   Label
# 0              54865               3  ...          0  BENIGN
# 1              55054             109  ...          0  BENIGN
# 2              55055              52  ...          0  BENIGN
# 3              46236              34  ...          0  BENIGN
# 4              54863               3  ...          0  BENIGN
#
# [5 rows x 79 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 225745 entries, 0 to 225744
# Data columns (total 79 columns):
#  Destination Port               225745 non-null int64
#  Flow Duration                  225745 non-null int64
#  Total Fwd Packets              225745 non-null int64
#  Total Backward Packets         225745 non-null int64
# Total Length of Fwd Packets     225745 non-null int64
#  Total Length of Bwd Packets    225745 non-null int64
#  Fwd Packet Length Max          225745 non-null int64
#  Fwd Packet Length Min          225745 non-null int64
#  Fwd Packet Length Mean         225745 non-null float64
#  Fwd Packet Length Std          225745 non-null float64
# Bwd Packet Length Max           225745 non-null int64
#  Bwd Packet Length Min          225745 non-null int64
#  Bwd Packet Length Mean         225745 non-null float64
#  Bwd Packet Length Std          225745 non-null float64
# Flow Bytes/s                    225745 non-null float64
#  Flow Packets/s                 225745 non-null float64
#  Flow IAT Mean                  225745 non-null float64
#  Flow IAT Std                   225745 non-null float64
#  Flow IAT Max                   225745 non-null int64
#  Flow IAT Min                   225745 non-null int64
# Fwd IAT Total                   225745 non-null int64
#  Fwd IAT Mean                   225745 non-null float64
#  Fwd IAT Std                    225745 non-null float64
#  Fwd IAT Max                    225745 non-null int64
#  Fwd IAT Min                    225745 non-null int64
# Bwd IAT Total                   225745 non-null int64
#  Bwd IAT Mean                   225745 non-null float64
#  Bwd IAT Std                    225745 non-null float64
#  Bwd IAT Max                    225745 non-null int64
#  Bwd IAT Min                    225745 non-null int64
# Fwd PSH Flags                   225745 non-null int64
#  Bwd PSH Flags                  225745 non-null int64
#  Fwd URG Flags                  225745 non-null int64
#  Bwd URG Flags                  225745 non-null int64
#  Fwd Header Length              225745 non-null int64
#  Bwd Header Length              225745 non-null int64
# Fwd Packets/s                   225745 non-null float64
#  Bwd Packets/s                  225745 non-null float64
#  Min Packet Length              225745 non-null int64
#  Max Packet Length              225745 non-null int64
#  Packet Length Mean             225745 non-null float64
#  Packet Length Std              225745 non-null float64
#  Packet Length Variance         225745 non-null float64
# FIN Flag Count                  225745 non-null int64
#  SYN Flag Count                 225745 non-null int64
#  RST Flag Count                 225745 non-null int64
#  PSH Flag Count                 225745 non-null int64
#  ACK Flag Count                 225745 non-null int64
#  URG Flag Count                 225745 non-null int64
#  CWE Flag Count                 225745 non-null int64
#  ECE Flag Count                 225745 non-null int64
#  Down/Up Ratio                  225745 non-null int64
#  Average Packet Size            225745 non-null float64
#  Avg Fwd Segment Size           225745 non-null float64
#  Avg Bwd Segment Size           225745 non-null float64
#  Fwd Header Length.1            225745 non-null int64
# Fwd Avg Bytes/Bulk              225745 non-null int64
#  Fwd Avg Packets/Bulk           225745 non-null int64
#  Fwd Avg Bulk Rate              225745 non-null int64
#  Bwd Avg Bytes/Bulk             225745 non-null int64
#  Bwd Avg Packets/Bulk           225745 non-null int64
# Bwd Avg Bulk Rate               225745 non-null int64
# Subflow Fwd Packets             225745 non-null int64
#  Subflow Fwd Bytes              225745 non-null int64
#  Subflow Bwd Packets            225745 non-null int64
#  Subflow Bwd Bytes              225745 non-null int64
# Init_Win_bytes_forward          225745 non-null int64
#  Init_Win_bytes_backward        225745 non-null int64
#  act_data_pkt_fwd               225745 non-null int64
#  min_seg_size_forward           225745 non-null int64
# Active Mean                     225745 non-null float64
#  Active Std                     225745 non-null float64
#  Active Max                     225745 non-null int64
#  Active Min                     225745 non-null int64
# Idle Mean                       225745 non-null float64
#  Idle Std                       225745 non-null float64
#  Idle Max                       225745 non-null int64
#  Idle Min                       225745 non-null int64
#  Label                          225745 non-null object
# dtypes: float64(24), int64(54), object(1)
# memory usage: 136.1+ MB

# %%
list(set(df.dtypes.tolist()))
# Out:
# [dtype('O'), dtype('int64'), dtype('float64')]

# %%
df_num = df.select_dtypes(include = ['float64', 'int64'])
df_num.head()
# Out:
#     Destination Port   Flow Duration  ...   Idle Max   Idle Min
# 0              54865               3  ...          0          0
# 1              55054             109  ...          0          0
# 2              55055              52  ...          0          0
# 3              46236              34  ...          0          0
# 4              54863               3  ...          0          0
#
# [5 rows x 78 columns]

# %%
df_num.hist(figsize=(30, 20), bins=10, xlabelsize=8, ylabelsize=8);
plt.savefig('drive/My Drive/BE FINAL/cic_final-code-results/EDA/hist.png')

# %%
from collections import Counter
Counter(df[" Label"])
# Out:
# Counter({'BENIGN': 97718, 'DDoS': 128027})

# %%
df.columns
# Out:
# Index([' Destination Port', ' Flow Duration', ' Total Fwd Packets',
#        ' Total Backward Packets', 'Total Length of Fwd Packets',
#        ' Total Length of Bwd Packets', ' Fwd Packet Length Max',
#        ' Fwd Packet Length Min', ' Fwd Packet Length Mean',
#        ' Fwd Packet Length Std', 'Bwd Packet Length Max',
#        ' Bwd Packet Length Min', ' Bwd Packet Length Mean',
#        ' Bwd Packet Length Std', 'Flow Bytes/s', ' Flow Packets/s',
#        ' Flow IAT Mean', ' Flow IAT Std', ' Flow IAT Max', ' Flow IAT Min',
#        'Fwd IAT Total', ' Fwd IAT Mean', ' Fwd IAT Std', ' Fwd IAT Max',
#        ' Fwd IAT Min', 'Bwd IAT Total', ' Bwd IAT Mean', ' Bwd IAT Std',
#        ' Bwd IAT Max', ' Bwd IAT Min', 'Fwd PSH Flags', ' Bwd PSH Flags',
#        ' Fwd URG Flags', ' Bwd URG Flags', ' Fwd Header Length',
#        ' Bwd Header Length', 'Fwd Packets/s', ' Bwd Packets/s',
#        ' Min Packet Length', ' Max Packet Length', ' Packet Length Mean',
#        ' Packet Length Std', ' Packet Length Variance', 'FIN Flag Count',
#        ' SYN Flag Count', ' RST Flag Count', ' PSH Flag Count',
#        ' ACK Flag Count', ' URG Flag Count', ' CWE Flag Count',
#        ' ECE Flag Count', ' Down/Up Ratio', ' Average Packet Size',
#        ' Avg Fwd Segment Size', ' Avg Bwd Segment Size',
#        ' Fwd Header Length.1', 'Fwd Avg Bytes/Bulk', ' Fwd Avg Packets/Bulk',
#        ' Fwd Avg Bulk Rate', ' Bwd Avg Bytes/Bulk', ' Bwd Avg Packets/Bulk',
#        'Bwd Avg Bulk Rate', 'Subflow Fwd Packets', ' Subflow Fwd Bytes',
#        ' Subflow Bwd Packets', ' Subflow Bwd Bytes', 'Init_Win_bytes_forward',
#        ' Init_Win_bytes_backward', ' act_data_pkt_fwd',
#        ' min_seg_size_forward', 'Active Mean', ' Active Std', ' Active Max',
#        ' Active Min', 'Idle Mean', ' Idle Std', ' Idle Max', ' Idle Min',
#        ' Label'],
#       dtype='object')

# %%
plt.figure(figsize = (180, 10))
boxplot = df.boxplot()
plt.savefig('drive/My Drive/BE FINAL/cic_final-code-results/EDA/boxplot.png')

# %%
from sklearn.preprocessing import LabelEncoder
encodings = dict()
for c in df.columns:
    #print df[c].dtype
    if df[c].dtype == "object":
        encodings[c] = LabelEncoder() #to give numerical label to char type labels.
        encodings[c]
        df[c] = encodings[c].fit_transform(df[c])

# %%
X = df.iloc[:,0:78]
Y = df.iloc[:,78]
C = df.iloc[:,78]
T = df.iloc[:,0:78]
Y.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name:  Label, dtype: int64

# %%
from sklearn.ensemble import ExtraTreesClassifier
import matplotlib.pyplot as plt
model = ExtraTreesClassifier()
model.fit(X,Y)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='auto',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_impurity_split=None,
#                      min_samples_leaf=1, min_samples_split=2,
#                      min_weight_fraction_leaf=0.0, n_estimators=100,
#                      n_jobs=None, oob_score=False, random_state=None, verbose=0,
#                      warm_start=False)

# %%
print(model.feature_importances_) #use inbuilt class feature_importances of tree based classifiers
# Out:
# [8.21800554e-02 8.17770932e-03 1.16043872e-02 6.64196050e-03
#  5.46484060e-03 2.64309310e-03 1.73239672e-02 1.77334920e-02
#  1.78487190e-02 5.99359558e-03 6.73049980e-02 1.01852999e-02
#  4.24850679e-02 3.15460036e-02 1.22459174e-03 2.47576937e-03
#  9.27994573e-04 3.78032995e-03 4.88044148e-03 2.81760949e-04
#  1.02825424e-02 6.32718803e-03 2.02295152e-02 1.23500055e-02
#  4.79732219e-04 1.37783409e-02 2.69797976e-03 8.06468849e-03
#  8.72007499e-03 3.87408221e-04 5.91142682e-03 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 9.90966833e-03 2.38239768e-03
#  4.41410744e-03 1.73079263e-03 2.03691473e-02 1.87970074e-02
#  2.69286561e-02 2.11823248e-02 2.38433996e-02 7.14430981e-04
#  5.73940065e-03 2.98575046e-06 1.77051505e-02 9.04291786e-02
#  6.83811153e-02 0.00000000e+00 0.00000000e+00 3.38051200e-02
#  4.61222619e-02 1.53135386e-02 5.90445241e-02 8.74685878e-03
#  0.00000000e+00 0.00000000e+00 0.00000000e+00 0.00000000e+00
#  0.00000000e+00 0.00000000e+00 1.06976822e-02 8.49556772e-03
#  1.18899222e-02 5.06331246e-03 8.69508587e-03 1.54530116e-03
#  9.85712351e-03 2.23063228e-02 1.52342439e-04 1.30955778e-04
#  2.17487987e-04 2.05223950e-04 1.13785899e-03 5.57555659e-04
#  1.13922906e-02 2.16091998e-03]

# %%
feat_importances = pd.Series(model.feature_importances_, index=X.columns)
plt.figure(figsize=(50,50))
feat_importances.nlargest(58).plot(kind='barh')
plt.show()
plt.savefig('drive/My Drive/BE FINAL/cic_final-code-results/EDA/imp.png')

# %%
X=X.drop([' Bwd PSH Flags',' Fwd URG Flags',' Bwd URG Flags',' RST Flag Count',' CWE Flag Count',' ECE Flag Count','Fwd Avg Bytes/Bulk',' Fwd Avg Packets/Bulk',' Fwd Avg Bulk Rate',' Bwd Avg Bytes/Bulk',' Bwd Avg Packets/Bulk','Bwd Avg Bulk Rate',' Active Max',' Bwd IAT Min',' act_data_pkt_fwd','Idle Mean',' Active Std',' Fwd Packet Length Max',' Idle Min',' Bwd Packets/s'], axis = 1) 
T=T.drop([' Bwd PSH Flags',' Fwd URG Flags',' Bwd URG Flags',' RST Flag Count',' CWE Flag Count',' ECE Flag Count','Fwd Avg Bytes/Bulk',' Fwd Avg Packets/Bulk',' Fwd Avg Bulk Rate',' Bwd Avg Bytes/Bulk',' Bwd Avg Packets/Bulk','Bwd Avg Bulk Rate',' Active Max',' Bwd IAT Min',' act_data_pkt_fwd','Idle Mean',' Active Std',' Fwd Packet Length Max',' Idle Min',' Bwd Packets/s'], axis = 1)

# %%
T.head()
# Out:
#     Destination Port   Flow Duration  ...   Idle Std   Idle Max
# 0              54865               3  ...        0.0          0
# 1              55054             109  ...        0.0          0
# 2              55055              52  ...        0.0          0
# 3              46236              34  ...        0.0          0
# 4              54863               3  ...        0.0          0
#
# [5 rows x 58 columns]
